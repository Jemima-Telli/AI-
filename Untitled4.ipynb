# %% [markdown]
# <a href="https://colab.research.google.com/github/Jemima-Telli/AI-/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import time
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
sns.set_style('darkgrid')
import shutil
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pd.read_excel("/content/sample_data/amur tigers data.xlsx")
# Out:
#       Country   Country Estimate    Year      Trend
# 0       Russia               386  2015.0      stable
# 1        China                20  2020.0  increasing
# 2     Thailand               145  2020.0  increasing
# 3    Malaysia                100  2018.0   declining
# 4      Myanmar                22  2018.0   declining
# 5    Indonesia               393  2014.0   declining
# 6        Nepal               235  2018.0     stable
# 7       Bhutan               103  2014.0      stable
# 8   Bangladesh               114  2018.0     unknown
# 9        India              2967  2018.0     unknown
# 10    Cambodia                 0  2015.0  extirpated
# 11       Total              4485     NaN         NaN
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['Country Estimate'].plot(kind='hist', bins=20, title='Country Estimate')
# ...

# %%
from matplotlib import pyplot as plt
_df_23['Year'].plot(kind='line', figsize=(8, 4), title='Year')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_18.groupby('Trend ').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import zipfile

# %%
from io import BytesIO

# %%
pd.read_csv("C:/Users/HP26LiFE/Downloads/atrw_detection_test (1).tar.gz", compression="gzip")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-75b193659639> in <cell line: 1>()
# ----> 1 pd.read_csv("C:/Users/HP26LiFE/Downloads/atrw_detection_test (1).tar.gz", compression="gzip")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
pd.read_csv("C:/Users/HP26LiFE/Downloads/atrw_detection_test.csv", compression="gzip")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-31f2c004d027> in <cell line: 1>()
# ----> 1 pd.read_csv("C:/Users/HP26LiFE/Downloads/atrw_detection_test.csv", compression="gzip")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
pd.read_csv('/content/atrw_detection_test.tar.gz')
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-21-0e2c265ef8d5> in <cell line: 1>()
# ----> 1 pd.read_csv('/content/atrw_detection_test.tar.gz')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import io

# %%
with io.BytesIO(open('atrw_detection_test.tar.gz', 'rb').read()) as f:
    reader = pd.read_csv(f)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-26-17e219549879> in <cell line: 1>()
#       1 with io.BytesIO(open('atrw_detection_test.tar.gz', 'rb').read()) as f:
# ----> 2     reader = pd.read_csv(f)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
with io.BytesIO(open('atrw_detection_test.tar.gz', 'rb').read()) as f:
    reader = pd.read_csv(f, encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-27-923a00403f24> in <cell line: 1>()
#       1 with io.BytesIO(open('atrw_detection_test.tar.gz', 'rb').read()) as f:
# ----> 2     reader = pd.read_csv(f, encoding='utf-8')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
with io.BytesIO(open('atrw_detection_test.tar.gz', 'rb').read()) as f:
    reader = pd.read_csv(f, encoding='latin1')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-28-1676389887e5> in <cell line: 1>()
#       1 with io.BytesIO(open('atrw_detection_test.tar.gz', 'rb').read()) as f:
# ----> 2     reader = pd.read_csv(f, encoding='latin1')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
with io.BytesIO(open('atrw_detection_test.tar.gz', 'rb').read()) as f:
    reader = pd.read_csv(f, encoding='latin1', header=3)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-29-f6501f1be084> in <cell line: 1>()
#       1 with io.BytesIO(open('atrw_detection_test.tar.gz', 'rb').read()) as f:
# ----> 2     reader = pd.read_csv(f, encoding='latin1', header=3)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
with io.BytesIO(open('atrw_detection_test.tar.gz', 'rb').read()) as f:
    reader = pd.read_csv(f, encoding='latin1', header=2)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-33-f6a40dba3758> in <cell line: 1>()
#       1 with io.BytesIO(open('atrw_detection_test.tar.gz', 'rb').read()) as f:
# ----> 2     reader = pd.read_csv(f, encoding='latin1', header=2)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
with io.BytesIO(open('atrw_detection_test.tar.gz', 'rb').read()) as f:
    reader = pd.read_csv(f, encoding='latin1', header=2, skiprows=[42])
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-34-242a2d4021a7> in <cell line: 1>()
#       1 with io.BytesIO(open('atrw_detection_test.tar.gz', 'rb').read()) as f:
# ----> 2     reader = pd.read_csv(f, encoding='latin1', header=2, skiprows=[42])
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
# ...

# %%
with io.open('atrw_detection_test.tar.gz', 'rb') as f:
    with io.BytesIO(f.read()) as g:
        reader = pd.read_csv(g, encoding='latin1', header=2, skiprows=[42])
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-35-38cd2fa8c74f> in <cell line: 1>()
#       1 with io.open('atrw_detection_test.tar.gz', 'rb') as f:
#       2     with io.BytesIO(f.read()) as g:
# ----> 3         reader = pd.read_csv(g, encoding='latin1', header=2, skiprows=[42])
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
with io.open('atrw_detection_test.tar.gz', 'rb') as f:
    with io.BytesIO(f.read()) as g:
        reader = pd.read_csv(g, encoding='latin1', header=2, skiprows=[42], buffer_size=1024 * 1024)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-07cffa1456e3> in <cell line: 1>()
#       1 with io.open('atrw_detection_test.tar.gz', 'rb') as f:
#       2     with io.BytesIO(f.read()) as g:
# ----> 3         reader = pd.read_csv(g, encoding='latin1', header=2, skiprows=[42], buffer_size=1024 * 1024)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
with io.open('atrw_detection_test.tar.gz', 'rb') as f:
    with io.BytesIO(f.read()) as g:
        reader = pd.read_csv(g, encoding='latin1', header=2, skiprows=[42])
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-37-38cd2fa8c74f> in <cell line: 1>()
#       1 with io.open('atrw_detection_test.tar.gz', 'rb') as f:
#       2     with io.BytesIO(f.read()) as g:
# ----> 3         reader = pd.read_csv(g, encoding='latin1', header=2, skiprows=[42])
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
with io.open('atrw_detection_test.tar.gz', 'rb') as f:
   with io.BytesIO(f.read()) as g:
reader = pd.read_csv(g, encoding='latin1', header=2, skiprows=[42], low_memory=True)
# Out:
#   File "<ipython-input-39-6f0e111adc18>", line 3
#     reader = pd.read_csv(g, encoding='latin1', header=2, skiprows=[42], low_memory=True)
#                                                                                         ^
# IndentationError: expected an indented block after 'with' statement on line 2

# %%
with io.open('atrw_detection_test.tar.gz', 'rb') as f:
   with io.BytesIO(f.read()) as g:
       reader = pd.read_csv(g, encoding='latin1', header=2, skiprows=[42], low_memory=True)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-40-698750db9f69> in <cell line: 1>()
#       1 with io.open('atrw_detection_test.tar.gz', 'rb') as f:
#       2    with io.BytesIO(f.read()) as g:
# ----> 3        reader = pd.read_csv(g, encoding='latin1', header=2, skiprows=[42], low_memory=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
pd.read_csv("C:/Users/HP26LiFE/Downloads/test.csv")
# Out:
#   File "<ipython-input-41-e490273b5d22>", line 1
#     pd.read_csv("C:\Users\HP26LiFE\Downloads\test")
#                                                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
pd.read_csv("C:/Users/HP26LiFE/Downloads/test.csv", encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-b76568464434> in <cell line: 1>()
# ----> 1 pd.read_csv("C:/Users/HP26LiFE/Downloads/test.csv", encoding='utf-8')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
fileName= input("C:/Users/HP26LiFE/Downloads/test.csv", encoding='utf-8')
fileScan= open("C:/Users/HP26LiFE/Downloads/test.csv", encoding='utf-8', 'r')
# Out:
#   File "<ipython-input-44-a1da678928c9>", line 2
#     fileScan= open("C:/Users/HP26LiFE/Downloads/test.csv", encoding='utf-8', 'r')
#                                                                                 ^
# SyntaxError: positional argument follows keyword argument

# %%
fileName = input("C:/Users/HP26LiFE/Downloads/test.csv", encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-50b058c37e11> in <cell line: 1>()
# ----> 1 fileName = input("C:/Users/HP26LiFE/Downloads/test.csv", encoding='utf-8')
#
# TypeError: Kernel.raw_input() got an unexpected keyword argument 'encoding'

# %%
fileName = open("C:/Users/HP26LiFE/Downloads/test.csv", encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-747c0962fd73> in <cell line: 1>()
# ----> 1 fileName = open("C:/Users/HP26LiFE/Downloads/test.csv", encoding='utf-8')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/HP26LiFE/Downloads/test.csv'

# %%
if os.path.exists("C:/Users/HP26LiFE/Downloads/test.csv"):
  fileName = open("C:/Users/HP26LiFE/Downloads/test.csv", encoding='utf-8')
else:
  print("File does not exist")
# Out:
# File does not exist

# %%
import pandas as pd

df = pd.read_csv(r"C:Users\HP26LiFE\Downloads\test\0001.jpg")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-49-e66d5b4ca8c7> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv(r"C:Users\HP26LiFE\Downloads\test\0001.jpg")
#       4 print(df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
pd.read_csv(r"D:\atrw_detection_test.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-c8a080302455> in <cell line: 1>()
# ----> 1 pd.read_csv(r"D:\atrw_detection_test.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.chdir('/content')

# %%
pd.read_csv('/content')
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-12-aceb7f70d824> in <cell line: 1>()
# ----> 1 pd.read_csv('/content')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import glob

# Get a list of all the CSV files in the directory.
csv_files = glob.glob('/content/*.csv')

# Read each CSV file into a DataFrame.
dfs = []
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate the DataFrames into a single DataFrame.
df = pd.concat(dfs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-b3468529ae35> in <cell line: 13>()
#      11
#      12 # Concatenate the DataFrames into a single DataFrame.
# ---> 13 df = pd.concat(dfs)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#
# ...

# %%
os.getcwd()
# Out:
# '/content'

# %%
pd.read_csv("/content")
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-15-03a51f897b3d> in <cell line: 1>()
# ----> 1 pd.read_csv("/content")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
